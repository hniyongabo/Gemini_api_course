# %%
# this is a project that consists of using the gemini API key in order to test it for myself
import google.generativeai as genai

# API configuration with API key created in Google Collab through 'secrets'

from google.colab import userdata

API_KEY=userdata.get('api_key')
genai.configure(api_key=API_KEY)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       2 import google.generativeai as genai
#       4 # API configuration with API key created in Google Collab through 'secrets'
# ----> 6 from google.colab import userdata
#       8 API_KEY=userdata.get('AIzaSyC1neRhJEiaV_Mu4ZbOMcUhCnE4jmkfcyQ')
#       9 genai.configure(api_key=API_KEY)
#
# ModuleNotFoundError: No module named 'google.colab'
